# %%
# median reduction over lat/long

# %matplotlib inline

from datetime import datetime
from datacube.analytics.analytics_engine import AnalyticsEngine
from datacube.execution.execution_engine import ExecutionEngine
from datacube.analytics.utils.analytics_utils import plot

# %%
# initialise AE/EE

a = AnalyticsEngine()
e = ExecutionEngine()
# Out:
# DEBUG:datacube.analytics.analytics_engine:Initialise Analytics Module.
# DEBUG:datacube.execution.execution_engine:Initialise Execution Module.

# %%
# Lake Burley Griffin
dimensions = {'longitude': {'range': (149.07, 149.18)},
              'latitude':  {'range': (-35.32, -35.28)},
              'time':      {'range': (datetime(1990, 1, 1), datetime(1990, 12, 31))}}

arrays = a.create_array(('LANDSAT 5', 'NBAR'), ['band_40'], dimensions, 'get_data')

median = a.apply_expression(arrays, 'median(array1, 1, 2)', 'medianXY')

e.execute_plan(a.plan)
# Out:
# DEBUG:datacube.analytics.analytics_engine:variable = band_40
# DEBUG:datacube.analytics.analytics_engine:function before = median(array1, 1, 2)
# DEBUG:datacube.analytics.analytics_engine:function after = median(get_data, 1, 2)

# %%
plot(e.cache['get_data'])
# Out:
# plot3D

# %%
plot(e.cache['medianXY'])
# Out:
# plot1D
